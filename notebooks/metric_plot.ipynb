# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
'''
metric = ['Billed Duration', 'Max Memory Used']
'''

def metric_plot(model, metric):
    if metric == 'Billed Duration':
        unit = ' (ms)'
    elif metric == 'Max Memory Used':
        unit = ' (MB)'
    elif metric == 'execution_times':
        unit = ' (second)'
        
    df = pd.read_csv('../results/spreadsheets/{0}_{1}.csv'.format(model, metric))
    cols = [str(x) for x in list(range(1, 31))]
    df_metric = pd.DataFrame({'mean': df[cols].mean(), 'stdev' : df[cols].std()})
    # import pdb;pdb.set_trace();
    fig = plt.figure(figsize=[10, 10])
    ax = fig.add_subplot(111)
    ax.scatter(df_metric['mean'], df_metric['stdev'])
    # ax.set_xlim(300, 325)
    # ax.set_ylim(17, 22)
    ax.set_title( metric + unit, fontsize=fontsize)
    ax.set_ylabel("Standard Deviation", fontsize=fontsize)
    ax.set_xlabel("Mean", fontsize=fontsize)
    fig.savefig('../results/graphs/{0}_{1}.png'.format(model, metric))

def execution_time_plot(model, metric='execution_times'):
    df = pd.read_csv('../results/spreadsheets/{0}_{1}.csv'.format(model, metric))
    mean = df.loc[0].mean()
    stdev = df.loc[0].std()
    print ("{0} {1} mean : {2}".format(model, metric, mean))
    print ("{0} {1} stdev : {2}".format(model, metric, stdev))

# %%
model = 'prophet'
metric = 'Billed Duration'
metric_plot(model, metric)

metric = 'Max Memory Used'  
metric_plot(model, metric)

metric = 'execution_times'  
execution_time_plot(model)
# Out:
# prophet execution_times mean : 801.5021634737651
# prophet execution_times stdev : 40.96878794926183

# %%
model = 'multi_regression'
metric = 'Billed Duration'
metric_plot(model, metric)

metric = 'Max Memory Used'  
metric_plot(model, metric)

metric = 'execution_times'  
execution_time_plot(model)
# Out:
# multi_regression execution_times mean : 158.71304442882538
# multi_regression execution_times stdev : 1.4736721127777659

# %%
model = 'neural_network_123'
metric = 'Billed Duration'
metric_plot(model, metric)

metric = 'Max Memory Used'  
metric_plot(model, metric)

metric = 'execution_times'  
execution_time_plot(model)
# Out:
# neural_network_123 execution_times mean : 116.0994033018748
# neural_network_123 execution_times stdev : 6.150550125646444

# %%
model = 'neural_network_456'
metric = 'Billed Duration'
metric_plot(model, metric)

metric = 'Max Memory Used'  
metric_plot(model, metric)

metric = 'execution_times'  
execution_time_plot(model)
# Out:
# > <ipython-input-70-51a913c8833c>(17)metric_plot()
# -> fig = plt.figure(figsize=[10, 10])
# (Pdb) df[cols].mean()
# 1     2644.444444
# 2     2778.240741
# 3     2640.740741
# 4     2648.611111
# 5     2757.175926
# 6     2770.833333
# 7     2760.416667
# 8     2659.722222
# 9     2671.759259
# 10    2765.046296
# 11    2770.138889
# 12    2673.379630
# 13    2769.212963
# 14    2796.296296
# 15    2733.796296
# 16    2668.750000
# 17    2772.453704
# 18    2658.796296
# 19    2758.564815
# 20    2653.935185
# 21    2747.453704
# 22    2629.166667
# 23    2640.740741
# 24    2745.833333
# 25    2665.740741
# 26    2766.435185
# 27    2865.509259
# 28    2680.324074
# 29    2749.305556
# 30    2746.990741
# dtype: float64
# (Pdb) df
#     activation learning_rate  learning_rate_init  n_iter_no_change  power_t  \
# 0     identity      constant              0.0010                10      0.1
# 1     identity      constant              0.0010                10      0.1
# 2     identity      constant              0.0010                10      0.1
# 3     identity      constant              0.0010                10      0.1
# 4     identity      constant              0.0010                10      0.1
# 5     identity      constant              0.0010                10      0.1
# 6     identity      constant              0.0010                10      0.5
# 7     identity      constant              0.0010                10      0.5
# 8     identity      constant              0.0010                10      0.5
# 9     identity      constant              0.0010                10      0.5
# 10    identity      constant              0.0010                10      0.5
# 11    identity      constant              0.0010                10      0.5
# 12    identity      constant              0.0010                20      0.1
# 13    identity      constant              0.0010                20      0.1
# 14    identity      constant              0.0010                20      0.1
# 15    identity      constant              0.0010                20      0.1
# 16    identity      constant              0.0010                20      0.1
# 17    identity      constant              0.0010                20      0.1
# 18    identity      constant              0.0010                20      0.5
# 19    identity      constant              0.0010                20      0.5
# 20    identity      constant              0.0010                20      0.5
# 21    identity      constant              0.0010                20      0.5
# 22    identity      constant              0.0010                20      0.5
# 23    identity      constant              0.0010                20      0.5
# 24    identity      constant              0.0001                10      0.1
# 25    identity      constant              0.0001                10      0.1
# 26    identity      constant              0.0001                10      0.1
# 27    identity      constant              0.0001                10      0.1
# 28    identity      constant              0.0001                10      0.1
# 29    identity      constant              0.0001                10      0.1
# ..         ...           ...                 ...               ...      ...
# 402       relu      adaptive              0.0010                20      0.5
# 403       relu      adaptive              0.0010                20      0.5
# 404       relu      adaptive              0.0010                20      0.5
# 405       relu      adaptive              0.0010                20      0.5
# 406       relu      adaptive              0.0010                20      0.5
# 407       relu      adaptive              0.0010                20      0.5
# 408       relu      adaptive              0.0001                10      0.1
# 409       relu      adaptive              0.0001                10      0.1
# 410       relu      adaptive              0.0001                10      0.1
# 411       relu      adaptive              0.0001                10      0.1
# 412       relu      adaptive              0.0001                10      0.1
# 413       relu      adaptive              0.0001                10      0.1
# 414       relu      adaptive              0.0001                10      0.5
# 415       relu      adaptive              0.0001                10      0.5
# 416       relu      adaptive              0.0001                10      0.5
# 417       relu      adaptive              0.0001                10      0.5
# 418       relu      adaptive              0.0001                10      0.5
# 419       relu      adaptive              0.0001                10      0.5
# 420       relu      adaptive              0.0001                20      0.1
# 421       relu      adaptive              0.0001                20      0.1
# 422       relu      adaptive              0.0001                20      0.1
# 423       relu      adaptive              0.0001                20      0.1
# 424       relu      adaptive              0.0001                20      0.1
# 425       relu      adaptive              0.0001                20      0.1
# 426       relu      adaptive              0.0001                20      0.5
# 427       relu      adaptive              0.0001                20      0.5
# 428       relu      adaptive              0.0001                20      0.5
# 429       relu      adaptive              0.0001                20      0.5
# 430       relu      adaptive              0.0001                20      0.5
# 431       relu      adaptive              0.0001                20      0.5
#
#     solver      tol     1     2     3  ...     21    22    23    24    25  \
# 0    lbfgs  0.00010  1400  1500  2000  ...   1900  1800  1400  1800  1500
# 1    lbfgs  0.00001  2000  1500  1400  ...   1400  1400  1800  1300  1400
# 2      sgd  0.00010  3500  3500  2400  ...   2100  3800  3900  3500  2400
# 3      sgd  0.00001  3600  2200  2100  ...   2000  2200  2100  2200  2300
# 4     adam  0.00010  3000  2800  4600  ...   4500  2800  4600  4000  2800
# 5     adam  0.00001  3000  2800  4600  ...   4000  4600  2900  5100  4600
# 6    lbfgs  0.00010  1300  1800  1500  ...   1400  1500  1500  1400  1800
# 7    lbfgs  0.00001  1400  1800  1400  ...   2100  1400  1500  1500  1500
# 430  4700  2900  2900  2600  2900
# 431  2900  2800  3000  5000  2700
#
# [432 rows x 37 columns]
# (Pdb) df.loc[0]
# activation            identity
# learning_rate         constant
# learning_rate_init       0.001
# n_iter_no_change            10
# power_t                    0.1
# solver                   lbfgs
# tol                     0.0001
# 1                         1400
# 2                         1500
# 3                         2000
# 4                         1800
# 5                         1500
# 6                         1500
# 7                         1500
# 8                         1500
# 9                         2000
# 10                        1500
# 11                        1800
# 12                        1700
# 13                        1800
# 14                        1500
# 15                        2200
# 16                        1700
# 17                        1400
# 18                        1400
# 19                        2100
# 20                        1400
# 21                        1900
# 22                        1800
# 23                        1400
# 24                        1800
# 25                        1500
# 26                        1800
# 27                        1800
# 28                        1600
# 29                        1600
# 30                        1800
# Name: 0, dtype: object
# (Pdb) exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-71-10c82e2ede57> in <module>
#       1 model = 'neural_network_456'
#       2 metric = 'Billed Duration'
# ----> 3 metric_plot(model, metric)
#       4
#       5 metric = 'Max Memory Used'
#
# <ipython-input-70-51a913c8833c> in metric_plot(model, metric)
#      15     df_metric = pd.DataFrame({'mean': df[cols].mean(), 'stdev' : df[cols].std()})
#      16     import pdb;pdb.set_trace();
# ---> 17     fig = plt.figure(figsize=[10, 10])
#      18     ax = fig.add_subplot(111)
#      19     ax.scatter(df_metric['mean'], df_metric['stdev'])
#
# <ipython-input-70-51a913c8833c> in metric_plot(model, metric)
#      15     df_metric = pd.DataFrame({'mean': df[cols].mean(), 'stdev' : df[cols].std()})
#      16     import pdb;pdb.set_trace();
# ---> 17     fig = plt.figure(figsize=[10, 10])
#      18     ax = fig.add_subplot(111)
#      19     ax.scatter(df_metric['mean'], df_metric['stdev'])
#
# ~/miniconda3/lib/python3.6/bdb.py in trace_dispatch(self, frame, event, arg)
#      49             return # None
#      50         if event == 'line':
# ---> 51             return self.dispatch_line(frame)
#      52         if event == 'call':
#      53             return self.dispatch_call(frame, arg)
#
# ~/miniconda3/lib/python3.6/bdb.py in dispatch_line(self, frame)
#      68         if self.stop_here(frame) or self.break_here(frame):
#      69             self.user_line(frame)
# ---> 70             if self.quitting: raise BdbQuit
#      71         return self.trace_dispatch
#      72
#
# BdbQuit:

# %%
model = 'svc_123'
metric = 'Billed Duration'
metric_plot(model, metric)

metric = 'Max Memory Used'  
metric_plot(model, metric)

metric = 'execution_times'  
execution_time_plot(model)
# Out:
# svc_123 execution_times mean : 116.72995609442393
# svc_123 execution_times stdev : 1.1277062346443958

# %%
model = 'svc_456'
metric = 'Billed Duration'
metric_plot(model, metric)

metric = 'Max Memory Used'  
metric_plot(model, metric)

metric = 'execution_times'  
execution_time_plot(model)
# Out:
# svc_456 execution_times mean : 115.32966309388479
# svc_456 execution_times stdev : 3.992215234292525

# %%
model = 'xgboost_123'
metric = 'Billed Duration'
metric_plot(model, metric)

metric = 'Max Memory Used'  
metric_plot(model, metric)

metric = 'execution_times'  
execution_time_plot(model)
# Out:
# xgboost_123 execution_times mean : 1238.64109313488
# xgboost_123 execution_times stdev : 17.43428356192574

# %%
model = 'xgboost_456'
metric = 'Billed Duration'
metric_plot(model, metric)

metric = 'Max Memory Used'  
metric_plot(model, metric)

metric = 'execution_times'  
execution_time_plot(model)
# Out:
# xgboost_456 execution_times mean : 1280.5638622840245
# xgboost_456 execution_times stdev : 38.82908339518496
